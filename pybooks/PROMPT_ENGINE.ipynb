# %%
import os
import pandas as pd
import numpy as np

# %%
FUSION_PROMPT = '''Контекст и цель:
Пожалуйста, объедините информацию из нескольких модальностей (речь, текст и описание видео) для создания краткой и точной суммаризации. Цель – получить компактную репрезентацию видео для векторного поиска.

Модальности:

Речь (ASR): {asr}
Текст (OCR): {ocr}
Описание видео (Captioning): {caption}

Инструкции:

- Проанализируйте данные из всех доступных модальностей. Если какая-либо модальность отсутствует (пустая), игнорируйте её при создании суммаризации.
- Извлеките основные и наиболее значимые аспекты из каждой доступной модальности.
- Объедините их в одну краткую и содержательную суммаризацию.

Формат ответа:
Создайте короткую суммаризацию в одном предложении, которая передает основное содержание видео. Избегайте излишних деталей и фокусируйтесь на ключевых аспектах.

Пример формата:
"Видео о [ключевая тема] с [важные аспекты речи], [основные тексты], и [основные визуальные элементы]."

Пример суммаризации:
"Видео о рецепте пиццы с пошаговым описанием процесса приготовления, включая список ингредиентов и визуальную демонстрацию приготовления."'''

# %%
FUSION_PROMPT.format(asr="aaaa", ocr='bbbb', caption='ccc')
# Out:
# 'Контекст и цель:\nПожалуйста, объедините информацию из нескольких модальностей (речь, текст и описание видео) для создания краткой и точной суммаризации. Цель – получить компактную репрезентацию видео для векторного поиска.\n\nМодальности:\n\nРечь (ASR): aaaa\nТекст (OCR): bbbb\nОписание видео (Captioning): ccc\n\nИнструкции:\n\n- Проанализируйте данные из всех доступных модальностей. Если какая-либо модальность отсутствует (пустая), игнорируйте её при создании суммаризации.\n- Извлеките основные и наиболее значимые аспекты из каждой доступной модальности.\n- Объедините их в одну краткую и содержательную суммаризацию.\n\nФормат ответа:\nСоздайте короткую суммаризацию в одном предложении, которая передает основное содержание видео. Избегайте излишних деталей и фокусируйтесь на ключевых аспектах.\n\nПример формата:\n"Видео о [ключевая тема] с [важные аспекты речи], [основные тексты], и [основные визуальные элементы]."\n\nПример суммаризации:\n"Видео о рецепте пиццы с пошаговым описанием процесса приготовления, включая список ингредиентов и визуальную демонстрацию приготовления."'
